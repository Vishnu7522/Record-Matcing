# %%
import pandas as pd
import numpy as np

# %%
Data_one = pd.read_excel("Records Matching Task.xlsx",
                          sheet_name = "data1" )
Data_one
# Out:
#             Order ID       Product ID  Qty
# 0     CA-2014-100006  TEC-PH-10002075  3.0
# 1     CA-2014-100090  FUR-TA-10003715  3.0
# 2     CA-2014-100090  OFF-BI-10001597  6.0
# 3     CA-2014-100293  OFF-PA-10000176  6.0
# 4     CA-2014-100328  OFF-BI-10000343  1.0
# ...              ...              ...  ...
# 9473  US-2017-169551  OFF-PA-10004100  3.0
# 9474  US-2017-169551  OFF-ST-10004835  3.0
# 9475  US-2017-169551  TEC-AC-10002018  3.0
# 9476  US-2017-169551  TEC-AC-10003033  2.0
# 9477  US-2017-169551  TEC-PH-10001363  2.0
#
# [9478 rows x 3 columns]

# %%
Data_one.head(20)
# Out:
#           Order ID       Product ID  Qty
# 0   CA-2014-100006  TEC-PH-10002075  3.0
# 1   CA-2014-100090  FUR-TA-10003715  3.0
# 2   CA-2014-100090  OFF-BI-10001597  6.0
# 3   CA-2014-100293  OFF-PA-10000176  6.0
# 4   CA-2014-100328  OFF-BI-10000343  1.0
# 5   CA-2014-100363  OFF-FA-10000611  2.0
# 6   CA-2014-100363  OFF-PA-10004733  3.0
# 7   CA-2014-100391  OFF-PA-10001471  2.0
# 8   CA-2014-100678  FUR-CH-10002602  3.0
# 9   CA-2014-100678  OFF-AR-10001868  2.0
# 10  CA-2014-100678  OFF-EN-10000056  3.0
# 11  CA-2014-100678  TEC-AC-10000474  3.0
# 12  CA-2014-100706  FUR-FU-10002268  6.0
# 13  CA-2014-100762  OFF-AR-10000380  4.0
# 14  CA-2014-100762  OFF-LA-10003930  2.0
# 15  CA-2014-100762  OFF-PA-10004082  2.0
# 16  CA-2014-100860  OFF-LA-10001982  5.0
# 17  CA-2014-100867  TEC-PH-10004922  6.0
# 18  CA-2014-100881  TEC-PH-10003273  3.0
# 19  CA-2014-100895  OFF-AR-10004511  2.0

# %%
Data_two = pd.read_excel("Records Matching Task.xlsx",
                          sheet_name = "data2" )
Data_two
# Out:
#             Order ID       Product ID  Qty
# 0     CA-2014-100090  FUR-TA-10003715  3.0
# 1     CA-2014-100090  OFF-BI-10001597  6.0
# 2     CA-2014-100293  OFF-PA-10000176  6.0
# 3     CA-2014-100328  OFF-BI-10000343  1.0
# 4     CA-2014-100363  OFF-FA-10000611  2.0
# ...              ...              ...  ...
# 9474  US-2017-169551  OFF-PA-10004100  3.0
# 9475  US-2017-169551  OFF-ST-10004835  3.0
# 9476  US-2017-169551  TEC-AC-10002018  3.0
# 9477  US-2017-169551  TEC-AC-10003033  2.0
# 9478  US-2017-169551  TEC-PH-10001363  2.0
#
# [9479 rows x 3 columns]

# %%
df = Data_two.equals(Data_one)

# %%
df
# Out:
# False

# %%
df_join = Data_one.merge(right=Data_two,
                   left_on = Data_one.columns.to_list(),
                   right_on = Data_two.columns.to_list(),
                   how = 'outer')

# %%
df_join
# Out:
#             Order ID       Product ID   Qty
# 0     CA-2014-100006  TEC-PH-10002075   3.0
# 1     CA-2014-100090  FUR-TA-10003715   3.0
# 2     CA-2014-100090  OFF-BI-10001597   6.0
# 3     CA-2014-100293  OFF-PA-10000176   6.0
# 4     CA-2014-100328  OFF-BI-10000343   1.0
# ...              ...              ...   ...
# 9981  US-2017-165344  OFF-BI-10003196  10.0
# 9982  US-2017-165358  TEC-CO-10001943   5.0
# 9983  US-2017-167920  OFF-AP-10000159   5.0
# 9984  US-2017-169502  OFF-AP-10001947   5.0
# 9985  US-2017-169551  FUR-BO-10001519   3.0
#
# [9986 rows x 3 columns]

# %%
Data_one.rename(columns=lambda Data_one : Data_one[0] + '_file1', inplace = True)
Data_one
# Out:
#              O_file1          P_file1  Q_file1
# 0     CA-2014-100006  TEC-PH-10002075      3.0
# 1     CA-2014-100090  FUR-TA-10003715      3.0
# 2     CA-2014-100090  OFF-BI-10001597      6.0
# 3     CA-2014-100293  OFF-PA-10000176      6.0
# 4     CA-2014-100328  OFF-BI-10000343      1.0
# ...              ...              ...      ...
# 9473  US-2017-169551  OFF-PA-10004100      3.0
# 9474  US-2017-169551  OFF-ST-10004835      3.0
# 9475  US-2017-169551  TEC-AC-10002018      3.0
# 9476  US-2017-169551  TEC-AC-10003033      2.0
# 9477  US-2017-169551  TEC-PH-10001363      2.0
#
# [9478 rows x 3 columns]

# %%
Data_two.rename(columns = lambda Data_two : Data_two[0] + '_file2', inplace = True)
Data_two
# Out:
#              O_file2          P_file2  Q_file2
# 0     CA-2014-100090  FUR-TA-10003715      3.0
# 1     CA-2014-100090  OFF-BI-10001597      6.0
# 2     CA-2014-100293  OFF-PA-10000176      6.0
# 3     CA-2014-100328  OFF-BI-10000343      1.0
# 4     CA-2014-100363  OFF-FA-10000611      2.0
# ...              ...              ...      ...
# 9474  US-2017-169551  OFF-PA-10004100      3.0
# 9475  US-2017-169551  OFF-ST-10004835      3.0
# 9476  US-2017-169551  TEC-AC-10002018      3.0
# 9477  US-2017-169551  TEC-AC-10003033      2.0
# 9478  US-2017-169551  TEC-PH-10001363      2.0
#
# [9479 rows x 3 columns]

# %%
df_join = Data_one.merge(right=Data_two,
                   left_on = Data_one.columns.to_list(),
                   right_on = Data_two.columns.to_list(),
                   how = 'outer')

# %%
df_join
# Out:
#              O_file1          P_file1  Q_file1         O_file2  \
# 0     CA-2014-100006  TEC-PH-10002075      3.0             NaN
# 1     CA-2014-100090  FUR-TA-10003715      3.0  CA-2014-100090
# 2     CA-2014-100090  OFF-BI-10001597      6.0  CA-2014-100090
# 3     CA-2014-100293  OFF-PA-10000176      6.0  CA-2014-100293
# 4     CA-2014-100328  OFF-BI-10000343      1.0  CA-2014-100328
# ...              ...              ...      ...             ...
# 9981             NaN              NaN      NaN  US-2017-165344
# 9982             NaN              NaN      NaN  US-2017-165358
# 9983             NaN              NaN      NaN  US-2017-167920
# 9984             NaN              NaN      NaN  US-2017-169502
# 9985             NaN              NaN      NaN  US-2017-169551
#
#               P_file2  Q_file2
# 0                 NaN      NaN
# 1     FUR-TA-10003715      3.0
# 2     OFF-BI-10001597      6.0
# 3     OFF-PA-10000176      6.0
# 4     OFF-BI-10000343      1.0
# ...

# %%
records_present_in_data1_missing_in_data2 = df_join.loc[df_join[Data_two.columns.to_list()].isnull().all(axis=1),Data_one.columns.to_list()]
records_present_in_data1_missing_in_data2
# Out:
#              O_file1          P_file1  Q_file1
# 0     CA-2014-100006  TEC-PH-10002075      3.0
# 10    CA-2014-100678  OFF-EN-10000056      3.0
# 19    CA-2014-100895  OFF-AR-10004511      2.0
# 35    CA-2014-101560  OFF-BI-10000309      3.0
# 61    CA-2014-102673  OFF-LA-10001771     12.0
# ...              ...              ...      ...
# 9390  US-2017-160836  OFF-AP-10001626      2.0
# 9403  US-2017-162558  FUR-FU-10002364      2.0
# 9420  US-2017-163657  OFF-BI-10000138      5.0
# 9427  US-2017-164056  FUR-TA-10001307      5.0
# 9435  US-2017-165456  FUR-CH-10003981      6.0
#
# [507 rows x 3 columns]

# %%
records_present_in_data1_missing_in_data2.count()
# Out:
# O_file1    507
# P_file1    507
# Q_file1    507
# dtype: int64

# %%
records_present_in_data2_missing_in_data1 = df_join.loc[df_join[Data_one.columns.to_list()].isnull().all(axis=1),Data_two.columns.to_list()]
records_present_in_data2_missing_in_data1
# Out:
#              O_file2          P_file2  Q_file2
# 9478  CA-2014-100706  TEC-AC-10001314      2.0
# 9479  CA-2014-100762  OFF-PA-10001815      3.0
# 9480  CA-2014-101427  OFF-AR-10002257      3.0
# 9481  CA-2014-102652  FUR-FU-10001918      7.0
# 9482  CA-2014-102869  OFF-PA-10000788      3.0
# ...              ...              ...      ...
# 9981  US-2017-165344  OFF-BI-10003196     10.0
# 9982  US-2017-165358  TEC-CO-10001943      5.0
# 9983  US-2017-167920  OFF-AP-10000159      5.0
# 9984  US-2017-169502  OFF-AP-10001947      5.0
# 9985  US-2017-169551  FUR-BO-10001519      3.0
#
# [508 rows x 3 columns]

# %%
records_present_in_data2_missing_in_data1.count()
# Out:
# O_file2    508
# P_file2    508
# Q_file2    508
# dtype: int64

# %%
df1=print(df_join['O_file2'].unique())
# Out:
# [nan 'CA-2014-100090' 'CA-2014-100293' ... 'US-2017-133781'
#  'US-2017-141943' 'US-2017-148866']

# %%
df2=df_join['O_file1'].unique().tolist()
df2
# Out:
# ['CA-2014-100006',
#  'CA-2014-100090',
#  'CA-2014-100293',
#  'CA-2014-100328',
#  'CA-2014-100363',
#  'CA-2014-100391',
#  'CA-2014-100678',
#  'CA-2014-100706',
#  'CA-2014-100762',
#  'CA-2014-100860',
#  'CA-2014-100867',
#  'CA-2014-100881',
#  'CA-2014-100895',
#  'CA-2014-100916',
#  'CA-2014-100972',
#  'CA-2014-101147',
#  'CA-2014-101175',
#  'CA-2014-101266',
#  'CA-2014-101364',
#  'CA-2014-101392',
#  'CA-2014-101462',
#  'CA-2014-101476',
#  'CA-2014-101560',
#  'CA-2014-101602',
#  'CA-2014-101770',
#  'CA-2014-101833',
#  'CA-2014-101931',
#  'CA-2014-102008',
#  'CA-2014-102085',
#  'CA-2014-102274',
#  'CA-2014-102295',
#  'CA-2014-102330',
#  'CA-2014-102645',
#  'CA-2014-102652',
#  'CA-2014-102673',
#  'CA-2014-102869',
#  'CA-2014-102988',
#  'CA-2014-103058',
#  'CA-2014-103086',
#  'CA-2014-103100',
#  'CA-2014-103191',
#  'CA-2014-103219',
#  'CA-2014-103310',
#  'CA-2014-103317',
#  'CA-2014-103331',
#  'CA-2014-103366',
#  'CA-2014-103373',
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-95-1fda7311f2bf> in <module>
# ----> 1 df2.counts(0)
#
# AttributeError: 'list' object has no attribute 'counts'

# %%
unique_records = df_join.nunique()
unique_records
# Out:
# O_file1    4875
# P_file1    1857
# Q_file1      16
# O_file2    4882
# P_file2    1854
# Q_file2      16
# dtype: int64
